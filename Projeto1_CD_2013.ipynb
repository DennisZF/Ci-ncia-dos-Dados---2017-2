# %%
#bibliotecas inicializadas 
import pandas as pd

# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib

# %%
#carregando a base de dados
dados2013 = pd.read_table("DOM2013.csv", encoding="windows-1252", sep=",")

# %%
#tamanho da base de dados
dados2013.shape
# Out:
# (148697, 99)

# %%
#criando as categorias
dados2013.V0201 = dados2013.V0201.astype('category')
dados2013.V4105 = dados2013.V4105.astype('category')
dados2013.V2103 = dados2013.V2103.astype('category')
dados2013.V2105 = dados2013.V2105.astype('category')
dados2013.V2107 = dados2013.V2107.astype('category')
dados2013.V2109 = dados2013.V2109.astype('category')

# %%
#Conversão legenda - Descrição 
dados2013.V0201.cat.categories = ('Particular Permanente','Particular Improvisado','Coletivo')
dados2013.V4105.cat.categories = ('URBANA - Cidade ou vila, área urbanizada','URBANA - Cidade ou vila, área não urbanizada','URBANA - Área urbana isolada','RURAL - Aglomerado rural de extensão urbana','RURAL - Aglomerado rural, isolado, povoado','RURAL - Aglomerado rural, isolado, núcleo','RURAL - Aglomerado rural, isolado, outros aglomerados','RURAL - Zona rural exclusive aglomerado rural')
dados2013.V2103.cat.categories = ('Sim','Não')
dados2013.V2105.cat.categories = ('Sim','Não')
dados2013.V2107.cat.categories = ('Sim','Não')
dados2013.V2109.cat.categories = ('Sim','Não')

# %%
#1° recorte: estado de são paulo
tabsp= dados2013[dados2013.UF==35]

# %%
#visualizando todas as colunas disponíveis na base de dados (verificar dicionário para identificação de cada coluna) 
list(tabsp)
# Out:
# ['Unnamed: 0',
#  'V0101',
#  'UF',
#  'V0102',
#  'V0103',
#  'V0104',
#  'V0105',
#  'V0106',
#  'V0201',
#  'V0202',
#  'V0203',
#  'V0204',
#  'V0205',
#  'V0206',
#  'V0207',
#  'V0208',
#  'V0209',
#  'V0210',
#  'V0211',
#  'V0212',
#  'V0213',
#  'V0214',
#  'V0215',
#  'V0216',
#  'V2016',
#  'V0217',
#  'V0218',
#  'V0219',
#  'V0220',
#  'V2020',
#  'V0221',
#  'V0222',
#  'V0223',
#  'V0224',
#  'V0225',
#  'V0226',
#  'V0227',
#  'V02270',
#  'V02271',
#  'V02272',
#  'V02273',
#  'V02274',
#  'V2027',
#  'V0228',
#  'V0229',
#  'V0230',
#  'V0231',
#  'V0232',
#  'V02321',
#  'V02322',
#  'V02323',
#  'V02324',
#  'V02325',
#  'V02326',
#  'V02327',
#  'V02424',
#  'V02425',
#  'V02426',
#  'V2032',
#  'V4105',
#  'V4107',
#  'V4600',
#  'V4601',
#  'V4602',
#  'V4604',
#  'V4605',
#  'V4606',
#  'V4607',
#  'V4608',
#  'V4609',
#  'V4610',
#  'V4611',
#  'V4614',
#  'UPA',
#  'V4617',
#  'V4618',
#  'V4620',
#  'V4621',
#  'V4622',
#  'V4624',
#  'V2101',
#  'V2103',
#  'V2105',
#  'V2107',
#  'V2109',
#  'V2113',
#  'V2115',
#  'V2117',
#  'V2121',
#  'V2123',
#  'V2124',
#  'V2126',
#  'V2128',
#  'V2130',
#  'V2132',
#  'V2134',
#  'V2138',
#  'V2139',
#  'V9992']

# %%
#corte da base de dados, pegando apenas as colunas desejadas
tabspcortada = tabsp.iloc[:,[6,8,59,72,81,82,83,84]]

# %%
#retirando valores indefinidos de renda
tabsprenda = tabspcortada[(tabspcortada.V4614 != 999999999999)]
tabsprenda.dropna()
# Out:
#         V0105                  V0201  \
# 91640     1.0  Particular Permanente
# 91642     3.0  Particular Permanente
# 91644     3.0  Particular Permanente
# 91645     2.0  Particular Permanente
# 91646     2.0  Particular Permanente
# 91647     1.0  Particular Permanente
# 91648     2.0  Particular Permanente
# 91650     1.0  Particular Permanente
# 91654     2.0  Particular Permanente
# 91655     5.0  Particular Permanente
# 91656     6.0  Particular Permanente
# 91657     2.0  Particular Permanente
# 91658     4.0  Particular Permanente
# 91659     3.0  Particular Permanente
# 91660     1.0  Particular Permanente
# 91661     1.0  Particular Permanente
# 91662     1.0  Particular Permanente
# 91663     4.0  Particular Permanente
# 91664     3.0  Particular Permanente
# 91665     1.0  Particular Permanente
# 91666     3.0  Particular Permanente
# 91667     5.0  Particular Permanente
# 91668     4.0  Particular Permanente
# 91669     2.0  Particular Permanente
# 91670     3.0  Particular Permanente
# 91671     1.0  Particular Permanente
# 91672     3.0  Particular Permanente
# 91673     2.0  Particular Permanente
# 91674     7.0  Particular Permanente
# 91675     4.0  Particular Permanente
# ...       ...                    ...
# 108564    5.0  Particular Permanente
# 108565    3.0  Particular Permanente
# 108567    4.0  Particular Permanente
# 108569    5.0  Particular Permanente
# 108570    1.0  Particular Permanente
# 108571    2.0  Particular Permanente
# 108573    1.0  Particular Permanente
# 108574    4.0  Particular Permanente
# 108575    2.0  Particular Permanente
# 108577    2.0  Particular Permanente
# 108578    2.0  Particular Permanente
# 108579    3.0  Particular Permanente
# 108580    3.0  Particular Permanente
# 108582    2.0  Particular Permanente
# 108583    2.0  Particular Permanente
# 108584    6.0  Particular Permanente
# 108589    3.0  Particular Permanente
# 108590    2.0  Particular Permanente
# 108591    3.0  Particular Permanente
# 108592    4.0  Particular Permanente
# 108593    4.0  Particular Permanente
# 108594    5.0  Particular Permanente
# 108595    2.0  Particular Permanente
# 108596    2.0  Particular Permanente
# 108597    2.0  Particular Permanente
# 108598    2.0  Particular Permanente
# 108600    3.0  Particular Permanente
# 108602    3.0  Particular Permanente
# 108603    2.0  Particular Permanente
# 108605    1.0  Particular Permanente
#
#                                            V4105   V4614 V2103 V2105 V2107  \
# 91640   URBANA - Cidade ou vila, área urbanizada     0.0   Não   Não   Não
# 91642   URBANA - Cidade ou vila, área urbanizada  2500.0   Não   Não   Não
# 91644   URBANA - Cidade ou vila, área urbanizada  1050.0   Sim   Sim   Sim
# 108574  URBANA - Cidade ou vila, área urbanizada  1950.0   Não   Não   Não
# 108575  URBANA - Cidade ou vila, área urbanizada  2450.0   Não   Não   Não
# 108577  URBANA - Cidade ou vila, área urbanizada  2730.0   Não   Não   Não
# 108578  URBANA - Cidade ou vila, área urbanizada  1500.0   Não   Não   Não
# 108579  URBANA - Cidade ou vila, área urbanizada  2478.0   Não   Não   Não
# 108580  URBANA - Cidade ou vila, área urbanizada  1800.0   Não   Não   Não
# 108582  URBANA - Cidade ou vila, área urbanizada  2600.0   Não   Não   Não
# 108583  URBANA - Cidade ou vila, área urbanizada  1783.0   Não   Não   Não
# 108584  URBANA - Cidade ou vila, área urbanizada   700.0   Não   Não   Não
# 108589  URBANA - Cidade ou vila, área urbanizada  4315.0   Não   Não   Não
# 108590  URBANA - Cidade ou vila, área urbanizada  6500.0   Não   Não   Não
# 108591  URBANA - Cidade ou vila, área urbanizada  3400.0   Não   Não   Não
# 108592  URBANA - Cidade ou vila, área urbanizada  2700.0   Sim   Não   Sim
# 108593  URBANA - Cidade ou vila, área urbanizada  2900.0   Não   Não   Não
# 108594  URBANA - Cidade ou vila, área urbanizada  5478.0   Não   Não   Não
# 108595  URBANA - Cidade ou vila, área urbanizada  2400.0   Não   Sim   Não
# 108596  URBANA - Cidade ou vila, área urbanizada  2070.0   Não   Não   Não
# 108597  URBANA - Cidade ou vila, área urbanizada  3000.0   Não   Não   Não
# 108598  URBANA - Cidade ou vila, área urbanizada  2100.0   Não   Não   Não
# 108600  URBANA - Cidade ou vila, área urbanizada  2200.0   Não   Não   Não
# 108602  URBANA - Cidade ou vila, área urbanizada  1678.0   Não   Não   Não
# 108603  URBANA - Cidade ou vila, área urbanizada  4800.0   Não   Não   Não
# 108605  URBANA - Cidade ou vila, área urbanizada     0.0   Não   Não   Não
#
#        V2109
# 91640    Não
# 91642    Não
# 91644    Sim
# 91645    Não
# 91646    Não
# 91647    Não
# 91648    Não
# 91650    Não
# 91654    Não
# 91655    Não
# 91656    Não
# 91657    Não
# 91658    Não
# 91659    Não
# 91660    Não
# 91661    Não
# 91662    Não
# 91663    Não
# 91664    Não
# 91665    Não
# 91666    Não
# 91667    Não
# 91668    Não
# 91669    Não
# 91670    Não
# 91671    Sim
# 91672    Não
# 91673    Não
# 91674    Não
# 91675    Não
# ...      ...
# 108564   Sim
# 108565   Não
# 108567   Não
# 108569   Não
# 108570   Sim
# 108571   Não
# 108573   Sim
# 108574   Não
# 108575   Não
# 108577   Não
# 108578   Não
# 108579   Não
# 108580   Não
# 108582   Não
# 108583   Não
# 108584   Não
# 108589   Não
# 108590   Não
# 108591   Não
# 108592   Não
# 108593   Não
# 108594   Não
# 108595   Não
# 108596   Não
# 108597   Não
# 108598   Não
# 108600   Não
# 108602   Não
# 108603   Não
# 108605   Não
#
# [12046 rows x 8 columns]
